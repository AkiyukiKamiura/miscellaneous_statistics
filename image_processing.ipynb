# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
img = cv2.imread('./main.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(img.shape)
plt.imshow(img)
# Out:
# (240, 240, 3)

# %%
tw, th = (60, 60)

w, h = img.shape[:2]
step_w, step_h = w//tw, h//th
